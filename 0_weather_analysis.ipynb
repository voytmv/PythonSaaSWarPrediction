# %%
import pandas as pd

# %%
data = pd.read_csv('data/raw_other_data_0/all_weather_by_hour.csv')

# %%
# here we can clearly see that each row represent the wide analysis of weather for each hour

data.head(25)
# Out:
#     city_latitude  city_longitude city_resolvedAddress      city_address  \
# 0         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 1         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 2         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 3         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 4         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 5         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 6         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 7         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 8         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 9         49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 10        49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# 11        49.4407         32.0637     Черкаси, Україна  Cherkasy,Ukraine
# ...

# %%
data.columns
# Out:
# Index(['city_latitude', 'city_longitude', 'city_resolvedAddress',
#        'city_address', 'city_timezone', 'city_tzoffset', 'day_datetime',
#        'day_datetimeEpoch', 'day_tempmax', 'day_tempmin', 'day_temp',
#        'day_feelslikemax', 'day_feelslikemin', 'day_feelslike', 'day_dew',
#        'day_humidity', 'day_precip', 'day_precipprob', 'day_precipcover',
#        'day_snow', 'day_snowdepth', 'day_windgust', 'day_windspeed',
#        'day_winddir', 'day_pressure', 'day_cloudcover', 'day_visibility',
#        'day_solarradiation', 'day_solarenergy', 'day_uvindex',
#        'day_severerisk', 'day_sunrise', 'day_sunriseEpoch', 'day_sunset',
#        'day_sunsetEpoch', 'day_moonphase', 'day_conditions', 'day_description',
#        'day_icon', 'day_source', 'day_preciptype', 'day_stations',
#        'hour_datetime', 'hour_datetimeEpoch', 'hour_temp', 'hour_feelslike',
#        'hour_humidity', 'hour_dew', 'hour_precip', 'hour_precipprob',
# ...

# %%
data.describe()
# Out:
#        city_latitude  city_longitude  city_tzoffset  day_datetimeEpoch  \
# count  190656.000000   190656.000000       190656.0       1.906560e+05
# mean       49.155629       30.222565            2.0       1.659910e+09
# std         1.310406        4.230812            0.0       8.255619e+06
# min        46.472500       22.285140            2.0       1.645654e+09
# 25%        48.429575       26.172358            2.0       1.652735e+09
# 50%        49.428750       31.015750            2.0       1.659906e+09
# 75%        50.066550       33.098575            2.0       1.667077e+09
# max        51.493700       37.814500            2.0       1.674166e+09
#
#          day_tempmax    day_tempmin       day_temp  day_feelslikemax  \
# count  190656.000000  190656.000000  190656.000000     190656.000000
# mean       15.386413       6.900469      11.096953         14.572734
# std         9.906868       7.821674       8.715765         10.774889
# ...

# %%
data.shape
# Out:
# (190656, 67)

# %%
data.isnull().sum()
# Out:
# city_latitude           0
# city_longitude          0
# city_resolvedAddress    0
# city_address            0
# city_timezone           0
#                        ..
# hour_severerisk         0
# hour_conditions         0
# hour_icon               0
# hour_source             0
# hour_stations           0
# Length: 67, dtype: int64
